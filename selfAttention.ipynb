# %% [markdown]
# rnn was state of art for seq2seq modelling, bt it suffers from
# - lot of time taken
# - slow as we feed one input at a time
# - word context cant be acheived completly as it only looks words before it
# - bidirection tried bt it also looks from left, looks from right seperatly

# %% [markdown]
# in attention every word can focus on words that comes after / before it
#
# self attention - attention on same sentence

# %% [markdown]
# through attention mechanism vectors will be more contexutal aware than normal input & positional emeddding
#
#
# - can be solved using parrlelising
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for every word we will have those 3 marices matlab, for every word in the corpus
